# %%
import numpy as np
import os
import cv2
import os
import json
from PIL import Image
import pickle

# %%
import tensorflow as tf
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.applications import DenseNet169
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, Dropout,BatchNormalization
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import TensorBoard

# %%
P = np.array(pickle.load(open("D:/P.pickle","rb")))

Q= np.array(pickle.load(open("D:/Q.pickle","rb")))

# %%
R = np.array(pickle.load(open("D:/R.pickle","rb")))

S= np.array(pickle.load(open("D:/S.pickle","rb")))

# %%
T = np.array(pickle.load(open("D:/T.pickle","rb")))

U= np.array(pickle.load(open("D:/U.pickle","rb")))

# %%
IMG_SIZE_1=250
IMG_SIZE_2=250

# %%
P=P/255.0
Q = to_categorical(Q, num_classes = 6)

# %%
R=R/255.0
S = to_categorical(S, num_classes = 6)

# %%
T=T/255.0
U = to_categorical(U, num_classes = 6)

# %%
#VGG-16

# Load the pre-trained VGG16 model
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(IMG_SIZE_1, IMG_SIZE_2, 3))

# Freeze the pre-trained layers
for layer in base_model.layers:
    layer.trainable = False

# Create a new model
model = Sequential()

# Add the base model to the new model
model.add(base_model)

# Add fully connected layers
model.add(Flatten())
model.add(Dense(512, activation = 'relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(256, activation = 'relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(128, activation = 'relu'))
model.add(BatchNormalization())
model.add(Dropout(0.25))

# Add the output layer
num_classes=6
model.add(Dense(num_classes, activation='softmax'))

# Define the optimizer
optimizer = SGD(learning_rate=0.01)

# Compile the model
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

model.summary()

# Create a TensorBoard callback
NAME = "TIG_VGG16_6_Steel"

tensorboard = TensorBoard(log_dir="logs/{}".format(NAME))
    
# Train the model with TensorBoard callback
model.fit(P, Q, batch_size=32, epochs=6, validation_data=(R, S),callbacks=[tensorboard])
    
# Save the model
model.save(f'VGG16_Steel_model.h5')

test_loss, test_acc = model.evaluate(T, U, verbose=1)
print('test_loss:', test_loss)
print('test_acc:', test_acc)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Functional)           (None, 7, 7, 512)         14714688
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               12845568
# _________________________________________________________________
# batch_normalization (BatchNo (None, 512)               2048
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 128)               512
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 6)                 774
# =================================================================
# Total params: 27,728,838
# Trainable params: 13,012,358
# Non-trainable params: 14,716,480
# _________________________________________________________________
# Epoch 1/6
#   1/757 [..............................] - ETA: 18s - loss: 2.6963 - accuracy: 0.2188WARNING:tensorflow:From C:\Users\HARSHA LAL\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\ops\summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
# 757/757 [==============================] - 337s 445ms/step - loss: 0.1868 - accuracy: 0.9473 - val_loss: 0.4869 - val_accuracy: 0.8850
# Epoch 2/6
# 757/757 [==============================] - 265s 350ms/step - loss: 0.0304 - accuracy: 0.9930 - val_loss: 0.5850 - val_accuracy: 0.8855
# Epoch 3/6
# 757/757 [==============================] - 267s 353ms/step - loss: 0.0159 - accuracy: 0.9968 - val_loss: 0.7720 - val_accuracy: 0.8692
# Epoch 4/6
# 757/757 [==============================] - 266s 352ms/step - loss: 0.0124 - accuracy: 0.9976 - val_loss: 0.6655 - val_accuracy: 0.8828
# Epoch 5/6
# 757/757 [==============================] - 266s 351ms/step - loss: 0.0115 - accuracy: 0.9976 - val_loss: 0.7821 - val_accuracy: 0.8835
# Epoch 6/6
# 757/757 [==============================] - 266s 352ms/step - loss: 0.0094 - accuracy: 0.9979 - val_loss: 0.7085 - val_accuracy: 0.8821
# 349/349 [==============================] - 89s 255ms/step - loss: 0.1076 - accuracy: 0.9684
# test_loss: 0.10759834945201874
# test_acc: 0.96836918592453

# %%
#VGG-19

base_model = VGG19(weights='imagenet', include_top=False, input_shape=(IMG_SIZE_1, IMG_SIZE_2, 3))

# Freeze the pre-trained layers
for layer in base_model.layers:
    layer.trainable = False

# Create a new model
model = Sequential()

# Add the base model to the new model
model.add(base_model)

# Add fully connected layers
model.add(Flatten())
model.add(Dense(512, activation = 'relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(256, activation = 'relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(128, activation = 'relu'))
model.add(BatchNormalization())
model.add(Dropout(0.25))

# Add the output layer
num_classes=6
model.add(Dense(num_classes, activation='softmax'))

# Define the optimizer
optimizer = SGD(learning_rate=0.01)

# Compile the model
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

model.summary()

# Create a TensorBoard callback
NAME = "TIG_VGG19_6_Steel"

tensorboard = TensorBoard(log_dir="logs/{}".format(NAME))
    
#Train the model with TensorBoard callback
model.fit(P, Q, batch_size=32, epochs=6, validation_data=(R, S),callbacks=[tensorboard])
    
# Save the model
model.save(f'VGG19_Steelmodel.h5')

test_loss, test_acc = model.evaluate(T, U, verbose=1)
print('test_loss:', test_loss)
print('test_acc:', test_acc)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg19 (Functional)           (None, 7, 7, 512)         20024384
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 25088)             0
# _________________________________________________________________
# dense_4 (Dense)              (None, 512)               12845568
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 128)               32896
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 128)               512
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 6)                 774
# =================================================================
# Total params: 33,038,534
# Trainable params: 13,012,358
# Non-trainable params: 20,026,176
# _________________________________________________________________
# Epoch 1/6
# 757/757 [==============================] - 388s 512ms/step - loss: 0.1799 - accuracy: 0.9489 - val_loss: 0.6549 - val_accuracy: 0.8325
# Epoch 2/6
# 757/757 [==============================] - 315s 416ms/step - loss: 0.0347 - accuracy: 0.9927 - val_loss: 0.6750 - val_accuracy: 0.8638
# Epoch 3/6
# 757/757 [==============================] - 316s 417ms/step - loss: 0.0225 - accuracy: 0.9949 - val_loss: 0.3520 - val_accuracy: 0.9019
# Epoch 4/6
# 757/757 [==============================] - 316s 417ms/step - loss: 0.0144 - accuracy: 0.9969 - val_loss: 0.4624 - val_accuracy: 0.8929
# Epoch 5/6
# 757/757 [==============================] - 316s 417ms/step - loss: 0.0114 - accuracy: 0.9977 - val_loss: 1.9131 - val_accuracy: 0.7228
# Epoch 6/6
# 757/757 [==============================] - 315s 416ms/step - loss: 0.0117 - accuracy: 0.9972 - val_loss: 0.6617 - val_accuracy: 0.8828
# 349/349 [==============================] - 102s 292ms/step - loss: 0.1721 - accuracy: 0.9418
# test_loss: 0.17212466895580292
# test_acc: 0.9417562484741211

# %%
#DenseNet169

# Load the pre-trained model
base_model = DenseNet169(weights='imagenet', include_top=False, input_shape=(IMG_SIZE_1, IMG_SIZE_2, 3))

# Freeze the pre-trained layers
for layer in base_model.layers:
    layer.trainable = False

# Create a new model
model = Sequential()

# Add the ResNet50 base model to the new model
model.add(base_model)

# Add fully connected layers
model.add(Flatten())
model.add(Dense(512, activation = 'relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(256, activation = 'relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(128, activation = 'relu'))
model.add(BatchNormalization())
model.add(Dropout(0.25))

# Add the output layer
num_classes=6
model.add(Dense(num_classes, activation='softmax'))

# Define the optimizer
optimizer = SGD(learning_rate=0.01)

# Compile the model
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

model.summary()

# Create a TensorBoard callback
NAME = "TIG_DenseNet169_6_Steel"

tensorboard = TensorBoard(log_dir="logs/{}".format(NAME))
    
# Train the model with TensorBoard callback
model.fit(P, Q, batch_size=32, epochs=6, validation_data=(R, S),callbacks=[tensorboard])
    
# Save the model
model.save(f'DenseNet169_Steelmodel.h5')

test_loss, test_acc = model.evaluate(T, U, verbose=1)
print('test_loss:', test_loss)
print('test_acc:', test_acc)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# densenet169 (Functional)     (None, 7, 7, 1664)        12642880
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 81536)             0
# _________________________________________________________________
# dense_8 (Dense)              (None, 512)               41746944
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 128)               32896
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 128)               512
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 6)                 774
# =================================================================
# Total params: 54,558,406
# Trainable params: 41,913,734
# Non-trainable params: 12,644,672
# _________________________________________________________________
# Epoch 1/6
#   2/757 [..............................] - ETA: 4:55 - loss: 2.7971 - accuracy: 0.1875WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.2278s vs `on_train_batch_end` time: 0.5452s). Check your callbacks.
# 757/757 [==============================] - 348s 460ms/step - loss: 0.1588 - accuracy: 0.9564 - val_loss: 0.2547 - val_accuracy: 0.9358
# Epoch 2/6
# 757/757 [==============================] - 247s 327ms/step - loss: 0.0233 - accuracy: 0.9962 - val_loss: 0.2736 - val_accuracy: 0.9379
# Epoch 3/6
# 757/757 [==============================] - 246s 326ms/step - loss: 0.0159 - accuracy: 0.9975 - val_loss: 0.3125 - val_accuracy: 0.9349
# Epoch 4/6
# 757/757 [==============================] - 247s 326ms/step - loss: 0.0122 - accuracy: 0.9976 - val_loss: 0.2990 - val_accuracy: 0.9332
# Epoch 5/6
# 757/757 [==============================] - 244s 322ms/step - loss: 0.0097 - accuracy: 0.9983 - val_loss: 0.3377 - val_accuracy: 0.9246
# Epoch 6/6
# 757/757 [==============================] - 243s 321ms/step - loss: 0.0076 - accuracy: 0.9988 - val_loss: 0.3054 - val_accuracy: 0.9333
# 349/349 [==============================] - 79s 226ms/step - loss: 0.0414 - accuracy: 0.9828
# test_loss: 0.04143897816538811
# test_acc: 0.9827957153320312

# %%
#Resnet-50

# Load the pre-trained ResNet50 model
base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(IMG_SIZE_1, IMG_SIZE_2, 3))

# Freeze the pre-trained layers
for layer in base_model.layers:
    layer.trainable = False

# Create a new model
model = Sequential()

# Add the ResNet50 base model to the new model
model.add(base_model)

# Add fully connected layers
model.add(Flatten())
model.add(Dense(512, activation = 'relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(256, activation = 'relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(128, activation = 'relu'))
model.add(BatchNormalization())
model.add(Dropout(0.25))

# Add the output layer
num_classes=6
model.add(Dense(num_classes, activation='softmax'))

# Define the optimizer
optimizer = SGD(learning_rate=0.01)

# Compile the model
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

model.summary()

# Create a TensorBoard callback
NAME = "TIG_Resnet50_6_Steel_model_"

tensorboard = TensorBoard(log_dir="logs/{}".format(NAME))
    
# Train the model with TensorBoard callback
model.fit(P, Q, batch_size=10, epochs=6, validation_data=(R, S),callbacks=[tensorboard])
    
# Save the model
model.save(f'resnet50_Steel_model.h5')

test_loss, test_acc = model.evaluate(T, U, verbose=1)
print('test_loss:', test_loss)
print('test_acc:', test_acc)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50 (Functional)        (None, 8, 8, 2048)        23587712
# _________________________________________________________________
# flatten (Flatten)            (None, 131072)            0
# _________________________________________________________________
# dense (Dense)                (None, 512)               67109376
# _________________________________________________________________
# batch_normalization (BatchNo (None, 512)               2048
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 128)               512
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 6)                 774
# =================================================================
# Total params: 90,865,670
# Trainable params: 67,276,166
# Non-trainable params: 23,589,504
# _________________________________________________________________
# Epoch 1/6
#    1/2421 [..............................] - ETA: 15s - loss: 2.8702 - accuracy: 0.1000WARNING:tensorflow:From C:\Users\HARSHA LAL\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\ops\summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
#    2/2421 [..............................] - ETA: 4:41 - loss: 2.6368 - accuracy: 0.1000WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0706s vs `on_train_batch_end` time: 0.1474s). Check your callbacks.
# 2421/2421 [==============================] - 342s 141ms/step - loss: 0.3470 - accuracy: 0.8941 - val_loss: 1.5596 - val_accuracy: 0.7554
# Epoch 2/6
# 2421/2421 [==============================] - 250s 103ms/step - loss: 0.1290 - accuracy: 0.9583 - val_loss: 7.7301 - val_accuracy: 0.0669
# Epoch 3/6
# 2421/2421 [==============================] - 251s 104ms/step - loss: 0.0839 - accuracy: 0.9731 - val_loss: 3.8127 - val_accuracy: 0.1176
# Epoch 4/6
# 2421/2421 [==============================] - 249s 103ms/step - loss: 0.0661 - accuracy: 0.9788 - val_loss: 8.8335 - val_accuracy: 0.6911
# Epoch 5/6
# 2421/2421 [==============================] - 248s 103ms/step - loss: 0.0600 - accuracy: 0.9806 - val_loss: 9.3982 - val_accuracy: 0.1173
# Epoch 6/6
# 2421/2421 [==============================] - 251s 104ms/step - loss: 0.0536 - accuracy: 0.9833 - val_loss: 10.3824 - val_accuracy: 0.2374
# 349/349 [==============================] - 71s 202ms/step - loss: 10.7748 - accuracy: 0.2280
# test_loss: 10.774823188781738
# test_acc: 0.22795699536800385

# %%
#Inseption-V-3

# Load the pre-trained model
base_model = InceptionV3(weights='imagenet', include_top=False, input_shape=(IMG_SIZE_1, IMG_SIZE_2, 3))

# Freeze the pre-trained layers
for layer in base_model.layers:
    layer.trainable = False

# Create a new model
model = Sequential()

# Add the ResNet50 base model to the new model
model.add(base_model)

# Add fully connected layers
model.add(Flatten())
model.add(Dense(512, activation = 'relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(256, activation = 'relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(128, activation = 'relu'))
model.add(BatchNormalization())
model.add(Dropout(0.25))

# Add the output layer
num_classes=6
model.add(Dense(num_classes, activation='softmax'))

# Define the optimizer
optimizer = SGD(learning_rate=0.01)

# Compile the model
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

model.summary()

# Create a TensorBoard callback
NAME = "TIG_InceptionV3_Steel_model_"

tensorboard = TensorBoard(log_dir="logs/{}".format(NAME))

# Train the model with TensorBoard callback
model.fit(P, Q, batch_size=10, epochs=6, validation_data=(R, S),callbacks=[tensorboard])
    
# Save the model
model.save(f'InceptionV3_Steel_modelh5')

test_loss, test_acc = model.evaluate(T, U, verbose=1)
print('test_loss:', test_loss)
print('test_acc:', test_acc)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception_v3 (Functional)    (None, 6, 6, 2048)        21802784
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 73728)             0
# _________________________________________________________________
# dense_4 (Dense)              (None, 512)               37749248
# _________________________________________________________________
# batch_normalization_97 (Batc (None, 512)               2048
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_98 (Batc (None, 256)               1024
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 128)               32896
# _________________________________________________________________
# batch_normalization_99 (Batc (None, 128)               512
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 6)                 774
# =================================================================
# Total params: 59,720,614
# Trainable params: 37,916,038
# Non-trainable params: 21,804,576
# _________________________________________________________________
# Epoch 1/6
#    2/2421 [..............................] - ETA: 11:09 - loss: 2.4855 - accuracy: 0.2500WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0562s vs `on_train_batch_end` time: 0.4896s). Check your callbacks.
# 2421/2421 [==============================] - 306s 126ms/step - loss: 0.2204 - accuracy: 0.9340 - val_loss: 0.2642 - val_accuracy: 0.9340
# Epoch 2/6
# 2421/2421 [==============================] - 191s 79ms/step - loss: 0.0582 - accuracy: 0.9840 - val_loss: 0.2516 - val_accuracy: 0.9347
# Epoch 3/6
# 2421/2421 [==============================] - 280s 116ms/step - loss: 0.0397 - accuracy: 0.9884 - val_loss: 0.2040 - val_accuracy: 0.9413
# Epoch 4/6
# 2421/2421 [==============================] - 249s 103ms/step - loss: 0.0310 - accuracy: 0.9906 - val_loss: 0.1991 - val_accuracy: 0.9397
# Epoch 5/6
# 2421/2421 [==============================] - 247s 102ms/step - loss: 0.0211 - accuracy: 0.9942 - val_loss: 0.2195 - val_accuracy: 0.9399
# Epoch 6/6
# 2421/2421 [==============================] - 305s 126ms/step - loss: 0.0212 - accuracy: 0.9936 - val_loss: 0.1640 - val_accuracy: 0.9482
# WARNING:tensorflow:From C:\Users\HARSHA LAL\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\training\tracking\tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From C:\Users\HARSHA LAL\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\training\tracking\tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: InceptionV3_Steel_modelh5\assets
# 349/349 [==============================] - 48s 137ms/step - loss: 0.0666 - accuracy: 0.9772
# test_loss: 0.06659401208162308
# test_acc: 0.977150559425354
