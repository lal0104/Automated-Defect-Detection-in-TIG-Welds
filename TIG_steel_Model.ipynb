# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
import os
import json
from PIL import Image
import pickle

# %%
A = np.array(pickle.load(open("D:/tig_welding_dataset/al5083/train_short/A.pickle","rb")))

B= np.array(pickle.load(open("D:/tig_welding_dataset/al5083/train_short/B.pickle","rb")))

# %%
IMG_SIZE_1=400
IMG_SIZE_2=487

# %%
import tensorflow as tf
from tensorflow.keras.applications import VGG19
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, Dropout
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.callbacks import TensorBoard

# Load the pre-trained VGG19 model
base_model = VGG19(weights='imagenet', include_top=False, input_shape=(IMG_SIZE_1, IMG_SIZE_2, 3))

# Freeze the pre-trained layers
for layer in base_model.layers:
    layer.trainable = False

# Create a new model
model = Sequential()

# Add the VGG19 base model to the new model
model.add(base_model)

# Add fully connected layers
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))

# Add the output layer
num_classes=6
model.add(Dense(num_classes, activation='softmax'))

# Define the optimizer
optimizer = SGD(learning_rate=0.01)

# Compile the model
model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Create a TensorBoard callback
NAME = "TIG_VGG19_SGD"

tensorboard = TensorBoard(log_dir="logs/{}".format(NAME))


# Train the model with TensorBoard callback
model.fit(A,B, batch_size=10, epochs=5, validation_split=0.2, callbacks=[tensorboard])

# Save the model
model.save('vgg19_model1.h5')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 [==============================] - 13s 0us/step
# Epoch 1/5
# 115/115 [==============================] - 517s 4s/step - loss: 946.4410 - accuracy: 0.6998 - val_loss: 1.4313 - val_accuracy: 0.6829
# Epoch 2/5
# 115/115 [==============================] - 540s 5s/step - loss: 1.2547 - accuracy: 0.7339 - val_loss: 1.1913 - val_accuracy: 0.6829
# Epoch 3/5
# 115/115 [==============================] - 522s 5s/step - loss: 1.0523 - accuracy: 0.7339 - val_loss: 1.0545 - val_accuracy: 0.6829
# Epoch 4/5
# 115/115 [==============================] - 499s 4s/step - loss: 1.1412 - accuracy: 0.7339 - val_loss: 0.9725 - val_accuracy: 0.6829
# Epoch 5/5
# 115/115 [==============================] - 512s 4s/step - loss: 0.8642 - accuracy: 0.7339 - val_loss: 0.9182 - val_accuracy: 0.6829

# %%
import tensorflow as tf
from tensorflow.keras.applications import VGG19
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import TensorBoard

# Load the pre-trained VGG19 model
base_model = VGG19(weights='imagenet', include_top=False, input_shape=(IMG_SIZE_1, IMG_SIZE_2, 3))

# Freeze the pre-trained layers
for layer in base_model.layers:
    layer.trainable = False

# Create a new model
model = Sequential()

# Add the VGG19 base model to the new model
model.add(base_model)

# Add fully connected layers
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))

# Add the output layer
num_classes=6
model.add(Dense(num_classes, activation='softmax'))

# Define the optimizer
optimizer = Adam(learning_rate=0.01)

# Compile the model
model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Create a TensorBoard callback
NAME = "TIG_VGG19_Adam"

tensorboard = TensorBoard(log_dir="logs/{}".format(NAME))


# Train the model with TensorBoard callback
model.fit(A,B, batch_size=10, epochs=5, validation_split=0.2, callbacks=[tensorboard])

# Save the model
model.save('vgg19_model2.h5')
# Out:
# Epoch 1/5
# 115/115 [==============================] - 533s 5s/step - loss: 27.3733 - accuracy: 0.8045 - val_loss: 0.3356 - val_accuracy: 0.9303
# Epoch 2/5
# 115/115 [==============================] - 516s 4s/step - loss: 0.9017 - accuracy: 0.9145 - val_loss: 0.0951 - val_accuracy: 0.9582
# Epoch 3/5
# 115/115 [==============================] - 528s 5s/step - loss: 0.2896 - accuracy: 0.9267 - val_loss: 0.1230 - val_accuracy: 0.9582
# Epoch 4/5
# 115/115 [==============================] - 617s 5s/step - loss: 0.8109 - accuracy: 0.9075 - val_loss: 0.1252 - val_accuracy: 0.9547
# Epoch 5/5
# 115/115 [==============================] - 514s 4s/step - loss: 0.1960 - accuracy: 0.9468 - val_loss: 0.1241 - val_accuracy: 0.9582

# %%
import tensorflow as tf
from tensorflow.keras.applications import VGG19
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adagrad
from tensorflow.keras.callbacks import TensorBoard

# Load the pre-trained VGG19 model
base_model = VGG19(weights='imagenet', include_top=False, input_shape=(IMG_SIZE_1, IMG_SIZE_2, 3))

# Freeze the pre-trained layers
for layer in base_model.layers:
    layer.trainable = False

# Create a new model
model = Sequential()

# Add the VGG19 base model to the new model
model.add(base_model)

# Add fully connected layers
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))

# Add the output layer
num_classes=6
model.add(Dense(num_classes, activation='softmax'))

# Define the optimizer
optimizer = Adagrad(learning_rate=0.01)

# Compile the model
model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Create a TensorBoard callback
NAME = "TIG_VGG19_Adagrad"

tensorboard = TensorBoard(log_dir="logs/{}".format(NAME))


# Train the model with TensorBoard callback
model.fit(A,B, batch_size=10, epochs=5, validation_split=0.2, callbacks=[tensorboard])

# Save the model
model.save('vgg19_model3.h5')
# Out:
# Epoch 1/5
# 115/115 [==============================] - 520s 5s/step - loss: 6.6533 - accuracy: 0.7766 - val_loss: 0.9891 - val_accuracy: 0.8084
# Epoch 2/5
# 115/115 [==============================] - 535s 5s/step - loss: 0.4646 - accuracy: 0.8778 - val_loss: 0.1373 - val_accuracy: 0.9617
# Epoch 3/5
# 115/115 [==============================] - 521s 5s/step - loss: 0.2491 - accuracy: 0.9215 - val_loss: 0.1239 - val_accuracy: 0.9652
# Epoch 4/5
# 115/115 [==============================] - 508s 4s/step - loss: 0.1769 - accuracy: 0.9389 - val_loss: 0.0922 - val_accuracy: 0.9652
# Epoch 5/5
# 115/115 [==============================] - 522s 5s/step - loss: 0.1465 - accuracy: 0.9459 - val_loss: 0.1013 - val_accuracy: 0.9652

# %%
import tensorflow as tf
from tensorflow.keras.applications import VGG19
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, Dropout
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.callbacks import TensorBoard

# Load the pre-trained VGG19 model
base_model = VGG19(weights='imagenet', include_top=False, input_shape=(IMG_SIZE_1, IMG_SIZE_2, 3))

# Freeze the pre-trained layers
for layer in base_model.layers:
    layer.trainable = False

# Create a new model
model = Sequential()

# Add the VGG19 base model to the new model
model.add(base_model)

# Add fully connected layers
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))

# Add the output layer
num_classes=6
model.add(Dense(num_classes, activation='softmax'))

# Define the optimizer
optimizer = RMSprop(learning_rate=0.01)

# Compile the model
model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Create a TensorBoard callback
NAME = "TIG_VGG19_RMSprop"

tensorboard = TensorBoard(log_dir="logs/{}".format(NAME))


# Train the model with TensorBoard callback
model.fit(A,B, batch_size=10, epochs=5, validation_split=0.2, callbacks=[tensorboard])

# Save the model
model.save('vgg19_model4.h5')
# Out:
# Epoch 1/5
# 115/115 [==============================] - 563s 5s/step - loss: 55.1680 - accuracy: 0.6824 - val_loss: 0.4127 - val_accuracy: 0.8780
# Epoch 2/5
# 115/115 [==============================] - 532s 5s/step - loss: 1.5735 - accuracy: 0.7086 - val_loss: 0.5618 - val_accuracy: 0.6829
# Epoch 3/5
# 115/115 [==============================] - 554s 5s/step - loss: 0.9134 - accuracy: 0.8063 - val_loss: 0.1117 - val_accuracy: 0.9617
# Epoch 4/5
# 115/115 [==============================] - 1114s 10s/step - loss: 0.7391 - accuracy: 0.8892 - val_loss: 0.1971 - val_accuracy: 0.9233
# Epoch 5/5
# 115/115 [==============================] - 1846s 16s/step - loss: 0.3292 - accuracy: 0.9031 - val_loss: 0.1360 - val_accuracy: 0.9617
